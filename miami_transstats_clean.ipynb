# %%
import pandas as pd

# %%
flights_MIA_201807 = pd.read_csv('Miami_201807.csv')
flights_MIA_201807.shape
flights_MIA_201807.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2018        3      7             1            7  2018-07-01
# 1  2018        3      7             8            7  2018-07-08
# 2  2018        3      7            14            6  2018-07-14
# 3  2018        3      7            15            7  2018-07-15
# 4  2018        3      7            21            6  2018-07-21
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  AIR_TIME  \
# 0                9E                  20363         9E   N295PQ  ...      39.0
# 1                9E                  20363         9E   N337PQ  ...     142.0
# 2                9E                  20363         9E   N296PQ  ...     136.0
# 3                9E                  20363         9E   N927XJ  ...     134.0
# 4                9E                  20363         9E   N309PQ  ...     145.0
#
#    FLIGHTS  DISTANCE  DISTANCE_GROUP CARRIER_DELAY WEATHER_DELAY  NAS_DELAY  \
# ...

# %%
flights_MIA_201807.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM',
#        'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID',
#        'ORIGIN_CITY_MARKET_ID', 'ORIGIN', 'ORIGIN_CITY_NAME',
#        'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST',
#        'DEST_CITY_NAME', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY',
#        'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DEL15', 'ARR_DELAY_GROUP', 'ARR_TIME_BLK', 'CANCELLED',
#        'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 50'],
#       dtype='object')

# %%
# subset flights that are from/to Miami from/to LA or New York
# flights from Miami
flights_MIA_201807[(flights_MIA_201807['ORIGIN_CITY_NAME'] == 'Miami, FL') & ((flights_MIA_201807['DEST_CITY_NAME'] == 'Los Angeles, CA') | (flights_MIA_201807['DEST_CITY_NAME'] == 'New York, NY'))]
# Out:
#        YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 26948  2018        3      7             1            7  2018-07-01
# 26949  2018        3      7             2            1  2018-07-02
# 26950  2018        3      7             3            2  2018-07-03
# 26951  2018        3      7             4            3  2018-07-04
# 26952  2018        3      7             5            4  2018-07-05
# 26953  2018        3      7             6            5  2018-07-06
# 26954  2018        3      7             7            6  2018-07-07
# 26955  2018        3      7             8            7  2018-07-08
# 26956  2018        3      7             9            1  2018-07-09
# 26957  2018        3      7            10            2  2018-07-10
# 26958  2018        3      7            11            3  2018-07-11
# 26959  2018        3      7            12            4  2018-07-12
# 26960  2018        3      7            13            5  2018-07-13
# ...
